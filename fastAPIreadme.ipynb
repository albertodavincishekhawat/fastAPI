# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Contents
# 1. Guidelines for document
# 2. video link & timestamp

# %% [markdown]
# ## Guidelines
# 1. Open this readme parellel to the actual code.
#
# 2. WRITTING THE CODE : Keep adding your understanding and steps of whatever process you are doing referencing to
#     1. File names and Headers
#     2. Screenshots
#     3. Diagrams
#
# 3. READING THE CODE : Just go through the code with "fastAPIreadme.ipynb".
#
# ![Screenshot from 2024-05-04 14-03-23.png](<attachment:Screenshot from 2024-05-04 14-03-23.png>)

# %% [markdown]
# ## [Link to the Video](https://www.youtube.com/watch?v=0sOvCWFmrtA&pp=ygUWcHl0aG9uIGFwaSBkZXZlbG9wbWVudA%3D%3D)
